# %%
#import the library sqlite3

import pandas as pd
import sqlite3 as sq
import mysql.connector

# %%
commune = pd.read_excel("donnees_communes.xlsx")

# %%
commune= commune[['REG','CODREG','COM','PMUN','PCAP','PTOT']]
commune = commune.rename(columns = {'REG':'reg_nom', 'CODREG':'reg_code', 'COM':'nom_commune'})
commune.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34991 entries, 0 to 34990
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   reg_nom      34991 non-null  object
#  1   reg_code     34991 non-null  float64
#  2   nom_commune  34991 non-null  object
#  3   PMUN         34991 non-null  float64
#  4   PCAP         34991 non-null  float64
#  5   PTOT         34991 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 1.6+ MB

# %%
foncier = pd.read_excel('Valeurs_foncières.xlsx')
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
geo = pd.read_excel('fr-esr-referentiel-geographique.xlsx')
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38916 entries, 0 to 38915
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   regrgp_nom         38916 non-null  object
#  1   reg_nom            38916 non-null  object
#  2   reg_nom_old        38916 non-null  object
#  3   aca_nom            38916 non-null  object
#  4   dep_nom            38916 non-null  object
#  5   com_code           38916 non-null  object
#  6   com_code1          38916 non-null  object
#  7   com_code2          38916 non-null  object
#  8   com_id             38916 non-null  object
#  9   com_nom_maj_court  38916 non-null  object
#  10  com_nom_maj        38916 non-null  object
#  11  com_nom            38916 non-null  object
# ...

# %%
geo_comm = pd.merge(geo, comm , how='outer')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 geo_comm = pd.merge(geo, comm , how='outer')
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
# ...

# %%
bien = foncier[["Type local","No voie","Type de voie","Voie","Code ID commune","Nombre pieces principales","Surface reelle bati","Surface Carrez du 1er lot"]]
bien = bien.rename(columns = {'Surface Carrez du 1er lot':'surface_local','Code ID commune':'id_codedep_code_commune','Nombre pieces principales' :'total_piece', 'Surface reelle bati':'surface_carrez'})
bien['id_bien'] = bien.index
bien
# Out:
#         Type local  No voie Type de voie               Voie  \
# 0      Appartement    190.0          RUE           CENTRALE
# 1      Appartement    347.0          RUE         DU CHATEAU
# 2      Appartement     58.0           AV      DU MONT BLANC
# 3           Maison    140.0          RUE  DE L'ABBE JOLIVET
# 4      Appartement     39.0          RUE             BUFFON
# ...            ...      ...          ...                ...
# 34164  Appartement      4.0          RUE          DE RIVOLI
# 34165  Appartement     38.0          RUE          DU TEMPLE
# 34166  Appartement     13.0          RUE     DES TOURNELLES
# 34167  Appartement     16.0          RUE        CHARLEMAGNE
# 34168  Appartement      3.0          RUE       SAINT-JOSEPH
#
#        id_codedep_code_commune  total_piece  surface_carrez  surface_local  \
# 0                          0.0          2.0            52.0          50.42
# 1                          1.0          3.0            48.0          48.22
# ...

# %%
comm = foncier[['Code postal', 'Commune', 'Code departement','Code ID commune','Code commune']]
comm.rename(columns = {'Code ID commune' : 'id_codedep_codecommune'})
# Out:
#        Code postal                Commune Code departement  \
# 0           1370.0  SAINT-ETIENNE-DU-BOIS                1
# 1           1170.0                 CHEVRY                1
# 2           1220.0      DIVONNE-LES-BAINS                1
# 3           1630.0                  PERON                1
# 4           1200.0             VALSERHONE                1
# ...            ...                    ...              ...
# 34164      75004.0               PARIS 04               75
# 34165      75004.0               PARIS 04               75
# 34166      75004.0               PARIS 04               75
# 34167      75004.0               PARIS 04               75
# 34168      75002.0               PARIS 02               75
#
#        id_codedep_codecommune  Code commune
# 0                         0.0           350
# 1                         1.0           103
# 2                         2.0           143
# 3                         3.0           288
# ...
